# %% [markdown]
# # Google Play Store analýza
#
# Teraz budeme pracovať so súborom `../data/playstore.csv`. Zistíme čo je jeho obsahom, vyčistíme dáta a pokúsime sa na otázky, ktoré vypadnú z toho, čo sa dozvieme o našich dátach.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Začneme opäť tým, že načítame všetky potrebné knižnice pomocou príkazy `import` a nastavýme im aliasy.
#
# Zároveň aj schováme otravné varovanie, ktoré nikto nemá rád.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#To hide Warning messages.
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Vytvoríme premennú `df`, kde načítame náš dataset. Rovno sa aj pozrieme, čo sa dnu nachádza.
#
# - [pandas.read_csv()](http://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.read_csv.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Ako vyzerá posledných 5 riadkov?**

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Aké sú rozmery našej tabuľky?**

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Aké stĺpce obsahuje naša tabuľka?**

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# Zase si môžeme všimnúť, že tabuľka obsahuje o jeden stĺpec viac ako by sme možno chceli. Zbavíme sa ho.

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# ## Príprava a čistenie dát
#
# Pre presnosť našich záverov, musíme sa najprv zbaviť divných alebo neplatných dát. Do tejto kategórie patria napríklad duplicitné alebo nulové dáta.
#
# **Koľko prázdnych dát obsahuje naša tabuľka?**
#
# - [pandas.isnull()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.isnull.html)
# - [pandas.DataFrame.sum()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Odstráň nulové hodnoty**
#
# - [pandas.DataFrame.dropna()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html)
#
# TIP: pozri sa na konfiguračnú hodnotu `inplace`

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Odstráň nulové hodnoty**
#
# - [pandas.DataFrame.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Aké má tabuľka rozmery teraz?**

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# Teraz sa pozrieme bližšie na dátové typy našich stĺpcov.
#
# - [pandas.DataFrame.dtypes](http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# Vôbec sa mi nepáči stĺpec `Reviews`, pretože chcem aby to bolo číslo. Pretypujem ho na datový typ `int64`.
#
# - [pandas.DataFrame.astype()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html)

# %%
# Priestor pre tvoju odpoved

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# ## Analýza
#
# Už sú naše dáta pripravené, môžeme sa začať pýtať ozajstné otázky.
#
# **Aké sú dostupné kategórie a koľko aplikácií ku nim patrí?**
#
# - [pandas.Series.value_counts()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# Keď sa nám podarilo vykresliť tabuľku, skúsme rovno graf (veľmi by sa mi páčil horizontálny stĺpcový graf o veľkosti 12x8 inches).

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# Poďme sa pozrieť teraz na samotné ohodnotenie. Použijeme metódu `describe`, ktorá nám povie hneď všetky zaujímavé štatistické dáta.
#
# - [pandas.Series.describe()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.describe.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# Na prvý pohľad veľmi uspokojivý výsledok, skúsime to ešte ukázať ako graf (dáta sa lepšie čítajú vizuálne). Použijeme knižnicu [Seaborn](https://seaborn.pydata.org/) (ktorej sme dali alias `sns`).
#
# Ideálny graf bude pre nás, niečo čo ukáže čo najviac údajov o rozložení hodnotení.
#
# - [seaborn.distplot()](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# Zistili sme, že aplikácie majú v priemere relatívne vysoké hodnotenie. Ako je to z ich relevanciou? Najprv sa pozrime, koľko máme k dispozícií používateľských recenzií. Pozrime sa na to rovnako ako v predchádzajúcom príklade.

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Aké aplikácie majú viac ako 10min hodnotení?**

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Aké je rozloženie aplikácií poďla toho či sú platené?**
#
# - [matplotlib.pyplot.pie()](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.pie.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Ktorá aplikácia je najdrahšia?**
#
# - [pandas.Series.max()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.max.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Ako vyzerá dostupnosť aplikácií pre jednotlivé verzie Android-u?**
#
# - [seaborn.countplot()](https://seaborn.pydata.org/generated/seaborn.countplot.html)
# - [pandas.Series.value_counts()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)

# %%
# Priestor pre tvoju odpoved

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# ## Hlbšia analýza
#
# Ešte skúsime zájsť trošku ďalej a pozrieme sa na aplikácie, ktoré majú hodnotenie presne `5.0`.
#
# Začneme tým, že si presunieme všetky aplikácie s hodnotením presne `5.0` do premennej s názvom `df_full` a pozrieme sa na prvých 5 záznamov.

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Koľko majú inštalácií?**
#
# - [seaborn.distplot()](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# Graf je super, ale skúsme sa ešte pozrieť na konkrétne čísla. Najprv si ich ale zoradíme podľa indexu.
#
# - [pandas.Series.sort_index()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.sort_index.html)
# - [pandas.Series.value_counts()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Aké aplikácie majú viac ako 1000 hodnotení?**

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# Pozrime sa ešte na relevanciu hodnotenia. Nakreslime si graf rozloženia recenzií pre aplikácie s hodnotením `5.0`.
#
# - [seaborn.distplot()](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Vytiahni aplikácie, ktoré majú aspoň 30 hodnotení**
#
# Výsledok ulož do premennej `df_full` a znova nakresli graf.
#
# - [seaborn.distplot()](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Koľko je takých aplikácií?**
#
# - [pandas.Series.count()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.count.html)

# %%
# Priestor pre tvoju odpoved

# %% [markdown]
# **Do akých žánrov patria? Sú platené?**
#
# TIP: Upravte si rozmery grafu
#
# - [seaborn.countplot()](https://seaborn.pydata.org/generated/seaborn.countplot.html)

# %%
# Priestor pre tvoju odpoved

# %%
# Priestor pre tvoju odpoved
